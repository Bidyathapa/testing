# %% [markdown]
# # test 101
# ## laws of motion
# ### law of inertia

# %% [markdown]
# $ y= mx + c$

# %% [markdown]
# $ a = \frac {F}{M}$

# %% [markdown]
# Equation:

# %% [markdown]
# $x^2 + bx+c=0$

# %% [markdown]
# Newton's gravitational force equation :

# %% [markdown]
# $ F= \frac{G m_1 m_2}{r^2}$

# %% [markdown]
# COulomb Interaction:

# %% [markdown]
# $ F= \frac{k q_1 q_2}{r^2}$

# %% [markdown]
# Lennard-Jones Potential:

# %%
![image](home/Github/lennard-jones_potential.png)
# Out:
# /usr/bin/sh: 1: Syntax error: word unexpected (expecting ")")

# %% [markdown]
# ![image](~/Github/lennard-jones_potential.png)

# %% [markdown]
# ![image](lennard-jones_potential.png)
